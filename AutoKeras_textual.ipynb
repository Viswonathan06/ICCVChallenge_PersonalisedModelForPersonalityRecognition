# %%
# !pip install git+https://github.com/keras-team/keras-tuner.git
# !pip install autokeras
# Out:
# Collecting git+https://github.com/keras-team/keras-tuner.git
#   Cloning https://github.com/keras-team/keras-tuner.git to /private/var/folders/l8/w575rm9n0b17wy1q0qlffjh40000gn/T/pip-req-build-or1on5om
#   Running command git clone -q https://github.com/keras-team/keras-tuner.git /private/var/folders/l8/w575rm9n0b17wy1q0qlffjh40000gn/T/pip-req-build-or1on5om
# Requirement already satisfied: packaging in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner==1.0.4) (20.9)
# Requirement already satisfied: numpy in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner==1.0.4) (1.20.1)
# Requirement already satisfied: requests in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner==1.0.4) (2.25.1)
# Requirement already satisfied: scipy in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner==1.0.4) (1.6.2)
# Collecting tensorboard
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 408 kB/s eta 0:00:01
# Requirement already satisfied: ipython in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner==1.0.4) (7.22.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pygments in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (2.8.1)
# Requirement already satisfied: appnope in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (52.0.0.post20210125)
# Requirement already satisfied: traitlets>=4.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (5.0.5)
# Requirement already satisfied: pickleshare in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (0.17.2)
# Requirement already satisfied: backcall in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (3.0.17)
# Requirement already satisfied: decorator in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner==1.0.4) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython->keras-tuner==1.0.4) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython->keras-tuner==1.0.4) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner==1.0.4) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->keras-tuner==1.0.4) (0.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from packaging->keras-tuner==1.0.4) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner==1.0.4) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner==1.0.4) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner==1.0.4) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner==1.0.4) (2020.12.5)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner==1.0.4) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner==1.0.4) (0.36.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.40.0-cp38-cp38-macosx_10_10_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 44.0 MB/s eta 0:00:01
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.17.3-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 10.6 MB/s eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 22.9 MB/s eta 0:00:01
# Collecting absl-py>=0.4
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: six in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard->keras-tuner==1.0.4) (1.15.0)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 31.6 MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 10.0 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: keras-tuner
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.4-py3-none-any.whl size=99107 sha256=57467365f9abb3671ff7556f9cec94bb74ecc933b19c908dc289114655e858b5
#   Stored in directory: /private/var/folders/l8/w575rm9n0b17wy1q0qlffjh40000gn/T/pip-ephem-wheel-cache-y8gwhb1e/wheels/de/4b/9b/7930314b7f11eec13b02d5ab518fdb7932652a289a916295c3
# Successfully built keras-tuner
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, tensorboard, kt-legacy, keras-tuner
# Successfully installed absl-py-0.13.0 cachetools-4.2.2 google-auth-1.35.0 google-auth-oauthlib-0.4.6 grpcio-1.40.0 keras-tuner-1.0.4 kt-legacy-1.0.4 markdown-3.3.4 oauthlib-3.1.1 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0
# Collecting autokeras
#   Downloading autokeras-1.0.16-py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 381 kB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from autokeras) (20.9)
# Collecting tensorflow<=2.5.0,>=2.3.0
#   Using cached tensorflow-2.5.0-cp38-cp38-macosx_10_11_x86_64.whl (195.7 MB)
# Requirement already satisfied: scikit-learn in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from autokeras) (0.24.1)
# Requirement already satisfied: pandas in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from autokeras) (1.2.4)
# Requirement already satisfied: keras-tuner>=1.0.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from autokeras) (1.0.4)
# Requirement already satisfied: numpy in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (1.20.1)
# Requirement already satisfied: tensorboard in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (2.6.0)
# Requirement already satisfied: ipython in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (7.22.0)
# Requirement already satisfied: kt-legacy in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (1.0.4)
# Requirement already satisfied: requests in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (2.25.1)
# Requirement already satisfied: scipy in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from keras-tuner>=1.0.2->autokeras) (1.6.2)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (3.17.3)
# Collecting numpy
#   Downloading numpy-1.19.5-cp38-cp38-macosx_10_9_x86_64.whl (15.6 MB)
#      |████████████████████████████████| 15.6 MB 637 kB/s eta 0:00:01
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-macosx_10_9_x86_64.whl (2.9 MB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (1.12.1)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: six~=1.15.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (1.15.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (0.36.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (3.7.4.3)
# Requirement already satisfied: absl-py~=0.10 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorflow<=2.5.0,>=2.3.0->autokeras) (0.13.0)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp38-cp38-macosx_10_10_x86_64.whl (3.7 MB)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from tensorboard->keras-tuner>=1.0.2->autokeras) (52.0.0.post20210125)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner>=1.0.2->autokeras) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner>=1.0.2->autokeras) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner>=1.0.2->autokeras) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.2->autokeras) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->keras-tuner>=1.0.2->autokeras) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner>=1.0.2->autokeras) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner>=1.0.2->autokeras) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner>=1.0.2->autokeras) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests->keras-tuner>=1.0.2->autokeras) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.2->autokeras) (3.1.1)
# Requirement already satisfied: decorator in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.17.2)
# Requirement already satisfied: pygments in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (3.0.17)
# Requirement already satisfied: traitlets>=4.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (5.0.5)
# Requirement already satisfied: pickleshare in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.7.5)
# Requirement already satisfied: backcall in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (4.8.0)
# Requirement already satisfied: appnope in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.1.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython->keras-tuner>=1.0.2->autokeras) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython->keras-tuner>=1.0.2->autokeras) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner>=1.0.2->autokeras) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython->keras-tuner>=1.0.2->autokeras) (0.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from packaging->autokeras) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from pandas->autokeras) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from pandas->autokeras) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->autokeras) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->autokeras) (1.0.1)
# Installing collected packages: numpy, grpcio, termcolor, tensorflow-estimator, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow, autokeras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.1
#     Uninstalling numpy-1.20.1:
#       Successfully uninstalled numpy-1.20.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.40.0
#     Uninstalling grpcio-1.40.0:
#       Successfully uninstalled grpcio-1.40.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed astunparse-1.6.3 autokeras-1.0.16 flatbuffers-1.12 gast-0.4.0 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 numpy-1.19.5 opt-einsum-3.3.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0

# %%
import autokeras as ak
import tensorflow as tf

# %%
# import keras
import os
import h5py
import numpy as np
import pickle
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Upload the validation and training metadata

# %%
URL = 'https://drive.google.com/file/d/1pIkuf9835uVLSJ8MI1JqutcGqG34UoDT/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
print(path)
#df = pd.read_pickle(path)
metadata_valid = pd.read_csv(path)
#metadata_valid.drop(['Unnamed: 0','TIMESTAMP','COUNTRY','EDUCATION','LANGUAGE'],inplace=True,axis=1)
metadata_valid.sort_values(['Video'],inplace=True)



metadata_valid.head()
# Out:
# https://drive.google.com/uc?export=download&id=1pIkuf9835uVLSJ8MI1JqutcGqG34UoDT
#    Unnamed: 0    Video  PART.1  PART.2            TIMESTAMP LANGUAGE  ID_y  \
# 0           0   1080.0     1.0    80.0  2019-05-17 20:07:00  Spanish     1
# 6           6   1080.0     1.0    80.0  2019-05-17 20:07:00  Spanish    80
# 1           1   1081.0    81.0     1.0  2019-05-17 18:46:00  Spanish     1
# 8           8   1081.0    81.0     1.0  2019-05-17 18:46:00  Spanish    81
# 2           2  38039.0    39.0    38.0  2019-07-20 16:34:00  Spanish    38
#
#   GENDER  AGE COUNTRY            EDUCATION  \
# 0      F   55   Spain            Secondary
# 6      M   20   Spain  Bachelor/uni_degree
# 1      F   55   Spain            Secondary
# 8      F   59   Spain              Primary
# 2      F   28   Spain       Masters_degree
#
#                                             SESSION1  \
# 0  /content/drive/MyDrive/Recordings/Validation/A...
# 6  /content/drive/MyDrive/Recordings/Validation/A...
# 1  /content/drive/MyDrive/Recordings/Validation/A...
# 8  /content/drive/MyDrive/Recordings/Validation/A...
# 2  /content/drive/MyDrive/Recordings/Validation/A...
#
#                                             SESSION2  \
# 0  /content/drive/MyDrive/Recordings/Validation/A...
# 6  /content/drive/MyDrive/Recordings/Validation/A...
# 1  /content/drive/MyDrive/Recordings/Validation/A...
# 8  /content/drive/MyDrive/Recordings/Validation/A...
# 2  /content/drive/MyDrive/Recordings/Validation/A...
#
#                                             SESSION3  \
# 0  /content/drive/MyDrive/Recordings/Validation/A...
# 6  /content/drive/MyDrive/Recordings/Validation/A...
# 1  /content/drive/MyDrive/Recordings/Validation/A...
# 8  /content/drive/MyDrive/Recordings/Validation/A...
# 2  /content/drive/MyDrive/Recordings/Validation/A...
#
#                                             SESSION4  OPENMINDEDNESS_Z  \
# 0  /content/drive/MyDrive/Recordings/Validation/A...         -0.421661
# 6  /content/drive/MyDrive/Recordings/Validation/A...          0.998121
# 1  /content/drive/MyDrive/Recordings/Validation/A...         -0.421661
# 8  /content/drive/MyDrive/Recordings/Validation/A...         -1.052676
# 2  /content/drive/MyDrive/Recordings/Validation/A...          0.209353
#
#    CONSCIENTIOUSNESS_Z  EXTRAVERSION_Z  AGREEABLENESS_Z  \
# 0             1.698023       -0.073130         0.982578
# 6             2.238958       -0.705557         0.095138
# 1             1.698023       -0.073130         0.982578
# 8             0.075217        0.084977         0.450114
# 2             0.886620        0.084977        -0.259838
#
#    NEGATIVEEMOTIONALITY_Z
# 0               -0.689069
# 6               -2.195649
# 1               -0.689069
# 8               -1.065714
# 2               -0.940166

# %%
metadata_valid['LANGUAGE'].uniqueue()
# Out:
# array(['Spanish', 'Catalan'], dtype=object)

# %%
URL = 'https://drive.google.com/file/d/1GCuSNtvPJTdOTh77jsjcbhItxY1WogJr/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
print(path)

# Reading training file.
metadata_train=pd.read_csv(path)
metadata_train.drop(['Unnamed: 0','LANGUAGE'],inplace=True,axis=1)
metadata_train.sort_values(['Video'],inplace=True)
metadata_train
# Out:
# https://drive.google.com/uc?export=download&id=1GCuSNtvPJTdOTh77jsjcbhItxY1WogJr
#      ID_y     Video  PART.1  PART.2 GENDER  AGE  OPENMINDEDNESS_Z  \
# 0       2    2003.0     2.0     3.0      F   29         -1.683690
# 1       3    2003.0     2.0     3.0      F   28         -0.263908
# 2       3    3005.0     3.0     5.0      F   28         -0.263908
# 5       5    3005.0     3.0     5.0      F   28         -0.894922
# 3       4    4096.0    96.0     4.0      M   31         -0.421661
# ..    ...       ...     ...     ...    ...  ...               ...
# 224   185  184185.0   185.0   184.0      M   59         -0.894922
# 226   188  188189.0   188.0   189.0      M   28          0.682614
# 228   189  188189.0   188.0   189.0      M   31          0.051600
# 229   191  191192.0   192.0   191.0      M   21          0.840368
# 231   192  191192.0   192.0   191.0      M   21         -0.737169
#
#      CONSCIENTIOUSNESS_Z  EXTRAVERSION_Z  AGREEABLENESS_Z  \
# 0               1.292321       -0.231237         1.160066
# 1               0.616152        0.243083         0.982578
# 2               0.616152        0.243083         0.982578
# 5              -0.871420       -1.812303        -1.502255
# 3              -0.330485       -0.705557         0.272626
# ..                   ...             ...              ...
# 224             1.157087       -0.705557         0.272626
# 226             0.075217        0.084977        -0.437326
# 228            -0.736186        0.875510        -0.792302
# 229             0.345684        0.401190         0.805090
# 231            -0.871420       -0.705557         0.272626
#
#      NEGATIVEEMOTIONALITY_Z  \
# 0                 -0.312424
# 1                 -0.437972
# 2                 -0.437972
# 5                  1.194157
# 3                 -0.312424
# ..                      ...
# 224               -1.191262
# 226               -1.316811
# 228               -0.563520
# 229               -2.948939
# 231                0.943060
#
#                                               SESSION1  \
# 0    /content/drive/MyDrive/Annotations/Animals/002...
# 1    /content/drive/MyDrive/Annotations/Animals/002...
# 2    /content/drive/MyDrive/Annotations/Animals/003...
# 5    /content/drive/MyDrive/Annotations/Animals/003...
# 3    /content/drive/MyDrive/Annotations/Animals/004...
# ..                                                 ...
# 224  /content/drive/MyDrive/Annotations/Animals/184...
# 226  /content/drive/MyDrive/Annotations/Animals/188...
# 228  /content/drive/MyDrive/Annotations/Animals/188...
# 229  /content/drive/MyDrive/Annotations/Animals/191...
# 231  /content/drive/MyDrive/Annotations/Animals/191...
#
#                                               SESSION2  \
# 0    /content/drive/MyDrive/Annotations/Talk/Annota...
# 1    /content/drive/MyDrive/Annotations/Talk/Annota...
# 2    /content/drive/MyDrive/Annotations/Talk/Annota...
# 5    /content/drive/MyDrive/Annotations/Talk/Annota...
# 3    /content/drive/MyDrive/Annotations/Talk/Annota...
# ..                                                 ...
# 224  /content/drive/MyDrive/Annotations/Talk/Annota...
# 226  /content/drive/MyDrive/Annotations/Talk/Annota...
# 228  /content/drive/MyDrive/Annotations/Talk/Annota...
# 229  /content/drive/MyDrive/Annotations/Talk/Annota...
# 231  /content/drive/MyDrive/Annotations/Talk/Annota...
#
#                                               SESSION3  \
# 0    /content/drive/MyDrive/Annotations/Lego/002003...
# 1    /content/drive/MyDrive/Annotations/Lego/002003...
# 2    /content/drive/MyDrive/Annotations/Lego/003005...
# 5    /content/drive/MyDrive/Annotations/Lego/003005...
# 3    /content/drive/MyDrive/Annotations/Lego/004096...
# ..                                                 ...
# 224  /content/drive/MyDrive/Annotations/Lego/184185...
# 226  /content/drive/MyDrive/Annotations/Lego/188189...
# 228  /content/drive/MyDrive/Annotations/Lego/188189...
# 229  /content/drive/MyDrive/Annotations/Lego/191192...
# 231  /content/drive/MyDrive/Annotations/Lego/191192...
#
#                                               SESSION4
# 0    /content/drive/MyDrive/Annotations/Ghost/00200...
# 1    /content/drive/MyDrive/Annotations/Ghost/00200...
# 2    /content/drive/MyDrive/Annotations/Ghost/00300...
# 5    /content/drive/MyDrive/Annotations/Ghost/00300...
# 3    /content/drive/MyDrive/Annotations/Ghost/00409...
# ..                                                 ...
# 224  /content/drive/MyDrive/Annotations/Ghost/18418...
# 226  /content/drive/MyDrive/Annotations/Ghost/18818...
# 228  /content/drive/MyDrive/Annotations/Ghost/18818...
# 229  /content/drive/MyDrive/Annotations/Ghost/19119...
# 231  /content/drive/MyDrive/Annotations/Ghost/19119...
#
# [232 rows x 15 columns]

# %%
URL = 'https://drive.google.com/file/d/1diTBP_I8gprd_FiDeP3E_nf0319Rc5kN/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
print(path)

# Reading training file.
metadata_test=pd.read_csv(path)
metadata_test.drop(['Unnamed: 0'],inplace=True,axis=1)
metadata_test.sort_values(['Video'],inplace=True)
metadata_test
# Out:
# https://drive.google.com/uc?export=download&id=1diTBP_I8gprd_FiDeP3E_nf0319Rc5kN
#        Video  PART.1  PART.2  ID_y GENDER  AGE  \
# 0     8105.0     8.0   105.0     8      F   41
# 14    8105.0     8.0   105.0   105      F   35
# 1    56109.0   109.0    56.0    56      F   27
# 16   56109.0   109.0    56.0   109      M   30
# 2    66067.0    66.0    67.0    66      M   37
# 3    66067.0    66.0    67.0    67      F   36
# 4    86087.0    86.0    87.0    86      M   26
# 7    86087.0    86.0    87.0    87      M   26
# 5    86089.0    89.0    86.0    86      M   26
# 11   86089.0    89.0    86.0    89      M   28
# 10   87088.0    88.0    87.0    88      F   26
# 8    87088.0    88.0    87.0    87      M   26
# 12   87089.0    87.0    89.0    89      M   28
# 6    87089.0    87.0    89.0    87      M   26
# 9    88089.0    89.0    88.0    88      F   26
# 13   88089.0    89.0    88.0    89      M   28
# 15  105117.0   105.0   117.0   105      F   35
# 18  105117.0   105.0   117.0   117      M   33
# 17  111130.0   111.0   130.0   111      F   19
# 19  111130.0   111.0   130.0   130      F   20
# 20  137138.0   138.0   137.0   137      M   22
# 21  137138.0   138.0   137.0   138      M   25
#
#                                              SESSION1  \
# 0   /content/drive/MyDrive/Recordings/Test/Annotat...
# 14  /content/drive/MyDrive/Recordings/Test/Annotat...
# 1   /content/drive/MyDrive/Recordings/Test/Annotat...
# 16  /content/drive/MyDrive/Recordings/Test/Annotat...
# 2   /content/drive/MyDrive/Recordings/Test/Annotat...
# 3   /content/drive/MyDrive/Recordings/Test/Annotat...
# 4   /content/drive/MyDrive/Recordings/Test/Annotat...
# 7   /content/drive/MyDrive/Recordings/Test/Annotat...
# 5   /content/drive/MyDrive/Recordings/Test/Annotat...
# 11  /content/drive/MyDrive/Recordings/Test/Annotat...
# 10  /content/drive/MyDrive/Recordings/Test/Annotat...
# 8   /content/drive/MyDrive/Recordings/Test/Annotat...
# 12  /content/drive/MyDrive/Recordings/Test/Annotat...
# 6   /content/drive/MyDrive/Recordings/Test/Annotat...
# 9   /content/drive/MyDrive/Recordings/Test/Annotat...
# 13  /content/drive/MyDrive/Recordings/Test/Annotat...
# 15  /content/drive/MyDrive/Recordings/Test/Annotat...
# 18  /content/drive/MyDrive/Recordings/Test/Annotat...
# 17  /content/drive/MyDrive/Recordings/Test/Annotat...
# 19  /content/drive/MyDrive/Recordings/Test/Annotat...
# 20  /content/drive/MyDrive/Recordings/Test/Annotat...
# 21  /content/drive/MyDrive/Recordings/Test/Annotat...
#
#                                              SESSION2  \
# 0   /content/drive/MyDrive/Recordings/Test/Annotat...
# 14  /content/drive/MyDrive/Recordings/Test/Annotat...
# 1   /content/drive/MyDrive/Recordings/Test/Annotat...
# 16  /content/drive/MyDrive/Recordings/Test/Annotat...
# 2   /content/drive/MyDrive/Recordings/Test/Annotat...
# 3   /content/drive/MyDrive/Recordings/Test/Annotat...
# 4   /content/drive/MyDrive/Recordings/Test/Annotat...
# 7   /content/drive/MyDrive/Recordings/Test/Annotat...
# 5   /content/drive/MyDrive/Recordings/Test/Annotat...
# 11  /content/drive/MyDrive/Recordings/Test/Annotat...
# 10  /content/drive/MyDrive/Recordings/Test/Annotat...
# 8   /content/drive/MyDrive/Recordings/Test/Annotat...
# 12  /content/drive/MyDrive/Recordings/Test/Annotat...
# 6   /content/drive/MyDrive/Recordings/Test/Annotat...
# 9   /content/drive/MyDrive/Recordings/Test/Annotat...
# 13  /content/drive/MyDrive/Recordings/Test/Annotat...
# 15  /content/drive/MyDrive/Recordings/Test/Annotat...
# 18  /content/drive/MyDrive/Recordings/Test/Annotat...
# 17  /content/drive/MyDrive/Recordings/Test/Annotat...
# 19  /content/drive/MyDrive/Recordings/Test/Annotat...
# 20  /content/drive/MyDrive/Recordings/Test/Annotat...
# 21  /content/drive/MyDrive/Recordings/Test/Annotat...
#
#                                              SESSION3  \
# 0   /content/drive/MyDrive/Recordings/Test/Annotat...
# 14  /content/drive/MyDrive/Recordings/Test/Annotat...
# 1   /content/drive/MyDrive/Recordings/Test/Annotat...
# 16  /content/drive/MyDrive/Recordings/Test/Annotat...
# 2   /content/drive/MyDrive/Recordings/Test/Annotat...
# 3   /content/drive/MyDrive/Recordings/Test/Annotat...
# 4   /content/drive/MyDrive/Recordings/Test/Annotat...
# 7   /content/drive/MyDrive/Recordings/Test/Annotat...
# 5   /content/drive/MyDrive/Recordings/Test/Annotat...
# 11  /content/drive/MyDrive/Recordings/Test/Annotat...
# 10  /content/drive/MyDrive/Recordings/Test/Annotat...
# 8   /content/drive/MyDrive/Recordings/Test/Annotat...
# 12  /content/drive/MyDrive/Recordings/Test/Annotat...
# 6   /content/drive/MyDrive/Recordings/Test/Annotat...
# 9   /content/drive/MyDrive/Recordings/Test/Annotat...
# 13  /content/drive/MyDrive/Recordings/Test/Annotat...
# 15  /content/drive/MyDrive/Recordings/Test/Annotat...
# 18  /content/drive/MyDrive/Recordings/Test/Annotat...
# 17  /content/drive/MyDrive/Recordings/Test/Annotat...
# 19  /content/drive/MyDrive/Recordings/Test/Annotat...
# 20  /content/drive/MyDrive/Recordings/Test/Annotat...
# 21  /content/drive/MyDrive/Recordings/Test/Annotat...
#
#                                              SESSION4
# 0   /content/drive/MyDrive/Recordings/Test/Annotat...
# 14  /content/drive/MyDrive/Recordings/Test/Annotat...
# 1   /content/drive/MyDrive/Recordings/Test/Annotat...
# 16  /content/drive/MyDrive/Recordings/Test/Annotat...
# 2   /content/drive/MyDrive/Recordings/Test/Annotat...
# 3   /content/drive/MyDrive/Recordings/Test/Annotat...
# 4   /content/drive/MyDrive/Recordings/Test/Annotat...
# 7   /content/drive/MyDrive/Recordings/Test/Annotat...
# 5   /content/drive/MyDrive/Recordings/Test/Annotat...
# 11  /content/drive/MyDrive/Recordings/Test/Annotat...
# 10  /content/drive/MyDrive/Recordings/Test/Annotat...
# 8   /content/drive/MyDrive/Recordings/Test/Annotat...
# 12  /content/drive/MyDrive/Recordings/Test/Annotat...
# 6   /content/drive/MyDrive/Recordings/Test/Annotat...
# 9   /content/drive/MyDrive/Recordings/Test/Annotat...
# 13  /content/drive/MyDrive/Recordings/Test/Annotat...
# 15  /content/drive/MyDrive/Recordings/Test/Annotat...
# 18  /content/drive/MyDrive/Recordings/Test/Annotat...
# 17  /content/drive/MyDrive/Recordings/Test/Annotat...
# 19  /content/drive/MyDrive/Recordings/Test/Annotat...
# 20  /content/drive/MyDrive/Recordings/Test/Annotat...
# 21  /content/drive/MyDrive/Recordings/Test/Annotat...

# %% [markdown]
# ## Upload the training, validation and test data

# %%
path_data = "/Users/hs4461/Desktop/DATA/UDIVA/"
path_text_features = "TextualFeatures/"
path_audio_features = "AudioFeatures/"


path_text_features_train = path_text_features+"Train/"
path_text_features_valid = path_text_features+"Validation/"
path_text_features_test = path_text_features+"Test/"

# %%
import glob

def import_data(path_features):
    
    listing=os.listdir(path_features)

    df_sentiment = pd.DataFrame(columns = ["video","context","person","minute","SentiMin", "SentiMax", "SentiAvg", "SentiStdev", "Senti0-0.20", "Senti0.21-0.40", "Senti0.41-0.60", "Senti0.61-0.80", "Senti0.81-1.00", "SentiTotal"])
    df_speechtrait = pd.DataFrame(columns =["video","context","person","minute","TraitMin","TraitMax","TraitAvg","TraitStdev","TraitTotal"])
    df_talkturn = pd.DataFrame(columns =["video","context","person","minute","TurnPercent","AvgWrdPerTurn","LongestTurn","TotalWrds","STDWrdPerTurn"])
    df_time = pd.DataFrame(columns=["video","context","person","minute","TimeMin","TimeMax","TimeAvg","TimeStdev","TimeTotal"])

    i = 0
    for folder in listing:
        if folder == ".DS_Store":
            continue
        else:
            print(folder)
            file_listing = os.listdir(path_features+folder+"/")
            for file in file_listing:
                print(file)
                fname =glob.glob(path_features+folder+'/'+file+'/output2/*.csv')
                #print(fname)
                for fn in fname:
                    #print(fn)
                    df_fn = pd.read_csv(fn,index_col=None)
                    filename = fn.split('/')[11].split('.')[0]
                    #'127184_lego_P2_10_Time'
                    feature_name = filename.split('_')[4]
                    if feature_name == "RawSenti":
                        df_sentiment.at[i,"video"]=filename.split('_')[0]
                        df_sentiment.at[i,"context"]=filename.split('_')[1]
                        df_sentiment.at[i,"person"]=filename.split('_')[2]
                        df_sentiment.at[i,"minute"]=filename.split('_')[3]
                        df_sentiment.at[i,4:]=df_fn.values
                    elif feature_name == "SpeechTrait":
                        df_speechtrait.at[i,"video"]=filename.split('_')[0]
                        df_speechtrait.at[i,"context"]=filename.split('_')[1]
                        df_speechtrait.at[i,"person"]=filename.split('_')[2]
                        df_speechtrait.at[i,"minute"]=filename.split('_')[3]
                        df_speechtrait.at[i,4:]=df_fn.values
                    elif feature_name == "TalkTurn":
                        df_talkturn.at[i,"video"]=filename.split('_')[0]
                        df_talkturn.at[i,"context"]=filename.split('_')[1]
                        df_talkturn.at[i,"person"]=filename.split('_')[2]
                        df_talkturn.at[i,"minute"]=filename.split('_')[3]
                        df_talkturn.at[i,4:]=df_fn.values
                    elif feature_name == "Time":
                        df_time.at[i,"video"]=filename.split('_')[0]
                        df_time.at[i,"context"]=filename.split('_')[1]
                        df_time.at[i,"person"]=filename.split('_')[2]
                        df_time.at[i,"minute"]=filename.split('_')[3]
                        df_time.at[i,4:]=df_fn.values
                    i = i+1
                    #print("========")
    df_sentiment['video']=df_sentiment['video'].astype(float)
    df_speechtrait['video']=df_speechtrait['video'].astype(float)
    df_talkturn['video']=df_talkturn['video'].astype(float)
    df_time['video']=df_time['video'].astype(float)
    df_sentiment.sort_values(['video', 'context','person','minute'],inplace=True)
    df_speechtrait.sort_values(['video', 'context','person','minute'],inplace=True)
    df_talkturn.sort_values(['video', 'context','person','minute'],inplace=True)
    df_time.sort_values(['video', 'context','person','minute'],inplace=True)
    df_textualall=pd.concat([df_sentiment.reset_index(drop=True),df_speechtrait.reset_index(drop=True),df_talkturn.reset_index(drop=True),df_time.reset_index(drop=True)], axis=1)
    df_textualall = df_textualall.loc[:,~df_textualall.columns.duplicated()]
    df_sentiment.dropna(inplace=True)
    df_speechtrait.dropna(inplace=True)
    df_talkturn.dropna(inplace=True)
    df_time.dropna(inplace=True)
    df_textualall.dropna(inplace=True)
    df_sentiment[['Senti0-0.20', 'Senti0.21-0.40','Senti0.41-0.60', 'Senti0.61-0.80', 'Senti0.81-1.00']]= df_sentiment[['Senti0-0.20', 'Senti0.21-0.40','Senti0.41-0.60', 'Senti0.61-0.80', 'Senti0.81-1.00']].div(df_sentiment[['Senti0-0.20', 'Senti0.21-0.40','Senti0.41-0.60', 'Senti0.61-0.80', 'Senti0.81-1.00']].sum(axis=1), axis=0)
    return df_sentiment, df_speechtrait, df_talkturn, df_time,df_textualall

# %%
df_sentiment_train, df_speechtrait_train, df_talkturn_train, df_time_train,df_textualall_train = import_data(path_text_features_train)
# Out:
# lego_transcripts_train
# 017150
# 043079
# 055125
# 112132
# /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3281: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   self.loc[index, col] = value
# 005134_v2
# 167168
# 140170
# 079142
# 144171
# 139189
# 011034
# 144176
# 113132
# 156169
# .DS_Store
# 027076
# 128129
# 010034
# 042084
# 191192
# 034035
# 035114
# 123188
# 151165
# 127129
# 009167
# 015126_v2
# 010011
# 078156
# 018025
# 127128
# 151164
# 101139
# 004115_v2
# 076143
# 106173
# 027118
# 122144
# 148151
# 025044
# 006007
# 164165
# 020150_v2
# 004096_v2
# 051100
# 102173
# 092108
# 139140
# 043143_v2
# 097098
# 023191
# 034121
# 082174
# 106108
# 101116
# 040090
# 013041_v2
# 055128
# 027154
# 079123
# 092096
# 097142
# 118125
# 171172
# 017027
# 100116
# 152153
# 006153
# 169171
# 020090
# 043152
# 018020
# 044156
# 025157
# 003005
# 005013_v2
# 015133
# 030079
# 127184
# 051076
# 009106
# 035166
# 172185
# 041084
# 044157
# 042092
# 023102_v2
# 118154
# 030082
# 114166
# 098126
# 030078
# 002003
# 102176
# 106148
# 112113
# 034133
# 092168
# 027113
# 184185
# 076122
# 173179
# 017149
# 188189
# 023191_v2
# 173176
# 144169
# 035040
# animals_transcripts_train
# 017150
# 018020_v2
# 043079
# 055125
# 112132
# 005134_v2
# 167168
# 140170
# 079142
# 144171
# 139189
# 011034
# 144176
# 113132
# 156169
# .DS_Store
# 027076
# 009106_v2
# 128129
# 010034
# 042084
# 191192
# 034035
# 035114
# 123188
# 151165
# 127129
# 009167
# 015126_v2
# 010011
# 078156
# 018025
# 127128
# 151164
# 101139
# 004115_v2
# 076143
# 106173
# 027118
# 122144
# 148151
# 025044
# 006007
# 164165
# 020150_v2
# 004096_v2
# 051100
# 102173
# 092108
# 139140
# 043143_v2
# 097098
# 034121
# 082174
# 106108
# 101116
# 040090
# 013041_v2
# 055128
# 027154
# 079123
# 092096
# 097142
# 118125
# 171172
# 017027
# 100116
# 152153
# 006153
# 169171
# 020090
# 043152
# 044156
# 025157
# 003005
# 005013_v2
# 015133
# 030079
# 127184
# 051076
# 035166
# 172185
# 041084
# 044157
# 042092
# 023102_v2
# 118154
# 030082
# 114166
# 098126
# 030078
# 002003
# 102176
# 106148
# 112113
# 034133
# 092168
# 027113
# 184185
# 076122
# 173179
# 017149
# 188189
# 023191_v2
# 173176
# 144169
# 035040
# talk_transcripts_train
# 017150
# 018020_v2
# 043079
# 055125
# 112132
# 005134_v2
# 167168
# 140170
# 079142
# 144171
# 139189
# 011034
# 144176
# 113132
# 156169
# .DS_Store
# 027076
# 009106_v2
# 128129
# 010034
# 042084
# 191192
# 034035
# 035114
# 123188
# 151165
# 127129
# 009167
# 015126_v2
# 010011
# 078156
# 018025
# 127128
# 151164
# 101139
# 004115_v2
# 076143
# 106173
# 027118
# 122144
# 148151
# 025044
# 006007
# 164165
# 020150_v2
# 004096_v2
# 051100
# 102173
# 092108
# 139140
# 043143_v2
# 097098
# 034121
# 082174
# 106108
# 101116
# 040090
# 013041_v2
# 055128
# 027154
# 079123
# 092096
# 097142
# 118125
# 171172
# 017027
# 100116
# 152153
# 006153
# 169171
# 020090
# 043152
# 044156
# 025157
# 003005
# 005013_v2
# 015133
# 030079
# 127184
# 051076
# 035166
# 172185
# 041084
# 044157
# 042092
# 023102_v2
# 118154
# 030082
# 114166
# 098126
# 030078
# 002003
# 102176
# 106148
# 112113
# 034133
# 092168
# 027113
# 184185
# 076122
# 173179
# 017149
# 188189
# 023191_v2
# 173176
# 144169
# 035040
# ghost_transcripts_train
# 017150
# 018020_v2
# 043079
# 055125
# 112132
# 005134_v2
# 167168
# 140170
# 079142
# 144171
# 139189
# 011034
# 144176
# 113132
# 156169
# .DS_Store
# 027076
# 128129
# 010034
# 042084
# 191192
# 034035
# 035114
# 123188
# 151165
# 127129
# 009167
# 015126_v2
# 010011
# 078156
# 018025
# 127128
# 151164
# 101139
# 004115_v2
# 076143
# 106173
# 027118
# 122144
# 148151
# 025044
# 006007
# 164165
# 020150_v2
# 004096_v2
# 051100
# 102173
# 092108
# 139140
# 043143_v2
# 097098
# 034121
# 082174
# 106108
# 101116
# 040090
# 013041_v2
# 055128
# 027154
# 079123
# 092096
# 097142
# 118125
# 171172
# 017027
# 100116
# 152153
# 006153
# 169171
# 020090
# 043152
# 044156
# 025157
# 003005
# 005013_v2
# 015133
# 030079
# 127184
# 051076
# 009106
# 035166
# 172185
# 041084
# 044157
# 042092
# 023102_v2
# 118154
# 030082
# 114166
# 098126
# 030078
# 002003
# 102176
# 106148
# 112113
# 034133
# 092168
# 027113
# 184185
# 076122
# 173179
# 017149
# 188189
# 023191_v2
# 173176
# 144169
# 035040

# %%
df_sentiment_valid, df_speechtrait_valid, df_talkturn_valid, df_time_valid,df_textualall_valid = import_data(path_text_features_valid)
# Out:
# ghost_transcripts1_val
# 119145
# 141183
# 038039
# 182183
# /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3281: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   self.loc[index, col] = value
# 141182
# 001080
# 085186
# 001081
# 180181
# 119124
# 085190
# 080081
# 183186
# 124145
# 146147
# 181182
# 052057
# 119190
# animals_transcripts1_val
# 119145
# 141183
# 038039
# 182183
# 141182
# 001080
# 085186
# 001081
# 180181
# 119124
# 085190
# 080081
# 183186
# 124145
# 146147
# 181182
# 052057
# 119190
# talk_transcripts1_val
# 119145
# 141183
# 038039
# 182183
# 141182
# 001080
# 085186
# 001081
# 180181
# 119124
# 085190
# 080081
# 183186
# 124145
# 146147
# 181182
# 052057
# 119190
# lego_transcripts1_val
# 119145
# 141183
# 038039
# 182183
# 141182
# 001080
# 085186
# 001081
# 180181
# 119124
# 085190
# 080081
# 183186
# 124145
# 146147
# 181182
# 052057
# 119190

# %%
df_sentiment_test, df_speechtrait_test, df_talkturn_test, df_time_test,df_textualall_test = import_data(path_text_features_test)
# Out:
# animals_transcripts1_test
# 088089
# .DS_Store
# 086087
# /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3281: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   self.loc[index, col] = value
# 086089
# 087089
# 111130
# 008105
# 087088
# 056109
# 105117
# 137138
# 066067
# lego_transcripts1_test
# 088089
# 086087
# 086089
# 087089
# 111130
# 008105
# 087088
# 056109
# 105117
# 137138
# 066067
# ghost_transcripts1_test
# 088089
# .DS_Store
# 086087
# 086089
# 087089
# 111130
# 008105
# 087088
# 056109
# 105117
# 137138
# 066067
# talk_transcripts1_testmasked
# 088089
# 086087
# 086089
# 087089
# 111130
# 008105
# 087088
# 056109
# 105117
# 137138
# 066067

# %%
def merge_with_metadata(df,metadata,HOW):
    #merge with the metadata on the video identity
    df_=df.merge(metadata,left_on="video",right_on="Video", how=HOW)
    #df_ = df_.loc[:,['video','person','minute','Video','PART.1','PART.2','ID_y']]
    #convert the ID_y to float to be able to compare it with PART.1 and PART.2
    df_['ID_y']=df_['ID_y'].astype(float)
    #keep only the lines where PART.1 and P1 match or P2 and PART.2 match
    c1 = ((df_['PART.1']==df_["ID_y"]) & (df_["person"] == "P1"))
    c2 = ((df_['PART.2']==df_["ID_y"]) & (df_["person"] == "P2"))
    c = c1 | c2
    df_ = df_[c]
    df_.drop_duplicates(subset =["video","context","person","minute"],inplace = True)
    #Remove unnecessary columns
    df_.drop(['SESSION1', 'SESSION2','SESSION3','SESSION4','Video','video','PART.1','PART.2','person'], axis = 1,inplace=True)
    return df_

# %% [markdown]
# ## Create different datasets according to the profile

# %%
def create_profile_dataset(df,column):
    if (column=='GENDER'):
        df_m=df[df['GENDER']=='M']
        df_f=df[df['GENDER']=='F']
        df_m_meta = df_m[['ID_y','minute']].copy()
        df_f_meta = df_f[['ID_y','minute']].copy()
        df_m.drop(['GENDER','context','AGE','ID_y','minute'], axis = 1,inplace=True)
        df_f.drop(['GENDER','context','AGE','ID_y','minute'], axis = 1,inplace=True)
        #df.drop(['context','AGE'], axis = 1,inplace=True)
        return df_m,df_f,df_m_meta,df_f_meta
    elif (column=='AGE'):
        df.drop(['context','GENDER'], axis = 1,inplace=True)
        df_ag1 = df[df['AGE'] <= 20]
        df_ag2 = df[(df['AGE'] > 20) & (df['AGE'] <=40)]
        df_ag3 = df[df['AGE'] > 40]
        df_ag1.drop(['AGE'], axis = 1,inplace=True)
        df_ag2.drop(['AGE'], axis = 1,inplace=True)
        df_ag3.drop(['AGE'], axis = 1,inplace=True)
        return df_ag1,df_ag2,df_ag3
    elif (column=='LANGUAGE'):
        df.drop(['GENDER','context','AGE'], axis = 1,inplace=True)
        lang = df['LANGUAGE'].unique()
        df_sp = df[df['LANGUAGE']== lang[0]]
        df_cat = df[df['LANGUAGE']==lang[1]]
        df_eng = df[df['LANGUAGE']==lang[2]]
        df_sp.drop(['LANGUAGE'], axis = 1,inplace=True)
        df_cat.drop(['LANGUAGE'], axis = 1,inplace=True)
        df_eng.drop(['LANGUAGE'], axis = 1,inplace=True)
        return df_sp,df_cat,df_eng
    elif (column=='context'):
        df.drop(['GENDER','AGE'], axis = 1,inplace=True)
        context = df['context'].unique()
        df_lego = df[df['context']== context[0]]
        df_animals = df[df['context']==context[1]]
        df_talk = df[df['context']==context[2]]
        df_ghost = df[df['context']==context[3]]
        df_lego.drop(['context'], axis = 1,inplace=True)
        df_animals.drop(['context'], axis = 1,inplace=True)
        df_talk.drop(['context'], axis = 1,inplace=True)
        df_ghost.drop(['context'], axis = 1,inplace=True)
        return df_lego,df_animals,df_talk,df_ghost

# %%
import csv
def prepare_data_for_ML(df,dataset):
    if dataset=='test':
        X = df.to_numpy()
        X = np.asarray(X).astype(np.float32)
        return X
    else:
        y_o = df.iloc[:,-5].to_numpy()
        y_c = df.iloc[:,-4].to_numpy()
        y_e = df.iloc[:,-3].to_numpy()
        y_a = df.iloc[:,-2].to_numpy()
        y_n = df.iloc[:,-1].to_numpy()
        ocean = df.iloc[:,-5:]
        X   = df.iloc[:,:-5].to_numpy()
        X = np.asarray(X).astype(np.float32)
        o_set = tf.data.Dataset.from_tensor_slices((X, y_o))
        c_set = tf.data.Dataset.from_tensor_slices((X, y_c))
        e_set = tf.data.Dataset.from_tensor_slices((X, y_e))
        a_set = tf.data.Dataset.from_tensor_slices((X, y_a))
        n_set = tf.data.Dataset.from_tensor_slices((X, y_n))
        return o_set,c_set,e_set,a_set,n_set,ocean

# %%
df_sentiment_valid_merged = merge_with_metadata(df_sentiment_valid,metadata_valid,"left")
df_speechtrait_valid_merged = merge_with_metadata(df_speechtrait_valid,metadata_valid,"left")
df_talkturn_valid_merged = merge_with_metadata(df_talkturn_valid,metadata_valid,"left")
df_time_valid_merged = merge_with_metadata(df_time_valid,metadata_valid,"left")
df_alltextual_valid_merged = merge_with_metadata(df_textualall_valid,metadata_valid,"left")



df_sentiment_train_merged = merge_with_metadata(df_sentiment_train,metadata_train,"left")
df_speechtrait_train_merged = merge_with_metadata(df_speechtrait_train,metadata_train,"left")
df_talkturn_train_merged = merge_with_metadata(df_talkturn_train,metadata_train,"left")
df_time_train_merged = merge_with_metadata(df_time_train,metadata_train,"left")
df_alltextual_train_merged = merge_with_metadata(df_textualall_train,metadata_train,"left")




df_sentiment_test_merged = merge_with_metadata(df_sentiment_test,metadata_test,"left")
df_speechtrait_test_merged = merge_with_metadata(df_speechtrait_test,metadata_test,"left")
df_talkturn_test_merged = merge_with_metadata(df_talkturn_test,metadata_test,"left")
df_time_test_merged = merge_with_metadata(df_time_test,metadata_test,"left")
df_alltextual_test_merged = merge_with_metadata(df_textualall_test,metadata_test,"left")

# %%
for iter_feature in ['talkturn','sentiment','time','speechtrait','alltextual']:
    for iter_set in ['valid','train','test']:
        print(f"Feature: {iter_feature}, Set: {iter_set}")
        exec(f"df_{iter_feature}_{iter_set}_male,df_{iter_feature}_{iter_set}_female,df_{iter_feature}_{iter_set}_male_meta,df_{iter_feature}_{iter_set}_female_meta=create_profile_dataset(df_{iter_feature}_{iter_set}_merged,'GENDER')")
        for iter_gender in ['male','female']:
            if iter_set=='test':
                exec(f"{iter_gender}_{iter_set}_{iter_feature}_X=prepare_data_for_ML(df_{iter_feature}_{iter_set}_{iter_gender},iter_set)")
            else:
                exec(f"{iter_gender}_{iter_set}_{iter_feature}_o,{iter_gender}_{iter_set}_{iter_feature}_c,{iter_gender}_{iter_set}_{iter_feature}_e,{iter_gender}_{iter_set}_{iter_feature}_a,{iter_gender}_{iter_set}_{iter_feature}_n,ocean_{iter_gender}_{iter_set}=prepare_data_for_ML(df_{iter_feature}_{iter_set}_{iter_gender},iter_set)")
 
            
    
#male_train_set_o,male_train_set_c,male_train_set_e,male_train_set_a,male_train_set_n = prepare_data_for_ML(df_talkturn_train_m)
#male_train_set_o,male_train_set_c,male_train_set_e,male_train_set_a,male_train_set_n = prepare_data_for_ML(df_talkturn_train_m)
#female_train_set_o,female_train_set_c,female_train_set_e,female_train_set_a,female_train_set_n = prepare_data_for_ML(df_talkturn_train_f)
#male_val_set_o,male_val_set_c,male_val_set_e,male_val_set_a,male_val_set_n = prepare_data_for_ML(df_talkturn_valid_m)
#female_val_set_o,female_val_set_c,female_val_set_e,female_val_set_a,female_val_set_n = prepare_data_for_ML(df_talkturn_valid_f)
# Out:
# Feature: talkturn, Set: valid
# Feature: talkturn, Set: train
# Feature: talkturn, Set: test
# Feature: sentiment, Set: valid
# Feature: sentiment, Set: train
# Feature: sentiment, Set: test
# Feature: time, Set: valid
# Feature: time, Set: train
# Feature: time, Set: test
# Feature: speechtrait, Set: valid
# Feature: speechtrait, Set: train
# Feature: speechtrait, Set: test
# Feature: alltextual, Set: valid
# /Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Exception ignored in: <function CapturableResource.__del__ at 0x7fef40b5af70>
# Traceback (most recent call last):
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 277, in __del__
#     self._destroy_resource()
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 924, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3022, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/hs4461/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
# AttributeError: 'NoneType' object has no attribute '__wrapped__'
# Feature: alltextual, Set: train
# Feature: alltextual, Set: test

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

model_dir='./Models'
results_dir = "./Results"
df_validation_loss =  pd.DataFrame(columns = ["Pers_Label","Feature","Profile_Split","val_loss"])
#df_predicted_val= pd.DataFrame(columns = ['o','c','e','a','n'])
#df_predicted_test= pd.DataFrame(columns = ['o','c','e','a','n'])


try:
    os.mkdir(results_dir)
except OSError:
    print ("Creation of the directory %s failed" % results_dir)
else:
    print ("Successfully created the directory %s " % results_dir)
    
try:
    os.mkdir(model_dir)
except OSError:
    print ("Creation of the directory %s failed" % model_dir)
else:
    print ("Successfully created the directory %s " % model_dir)    
    
#set early stopping criteria
#pat = 100 #this is the number of epochs with no improvment after which the training will stop
#early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)
nb_trial = 100
nb_epochs = 1000

def fit_and_evaluate(tf_train_set,tf_val_set,X_test,TRIALS,EPOCHS,model_filename,csv_logger):
    fit_results=None
    model_reg = None
    model_reg = ak.StructuredDataRegressor(max_trials=TRIALS, overwrite=True)
    fit_results = model_reg.fit(tf_train_set, epochs=EPOCHS, validation_split=0.15,callbacks=[csv_logger])#validation_data=tf_val_set
    validation_loss = model_reg.evaluate(tf_val_set)
    predicted_y_val = model_reg.predict(tf_val_set)
    predicted_y_test = model_reg.predict(X_test)
    model = model_reg.export_model()
    print(type(model))  # <class 'tensorflow.python.keras.engine.training.Model'>
    try:
        model.save(model_filename, save_format="tf")
    except Exception:
        model.save(model_filename+".h5")
    del model_reg
    del model
    return fit_results,validation_loss,predicted_y_val,predicted_y_test

i = 0

for iter_gender in ['male','female']:
    for iter_feature in ['speechtrait','talkturn','sentiment','time']:#'alltextual'
        for iter_pers_label in ['o','c','e','a','n']:
            print(f"Personality Label: {iter_pers_label}, Gender: {iter_gender}, Feature: {iter_feature}")
            logfilename = results_dir+f"/fit_results_{iter_feature}_{iter_pers_label}_{iter_gender}.csv"
            #model_checkpoint = ModelCheckpoint('./Models/TalkTurn_'+str(iter_gender)+'_'+str(iter_pers_label)+'.tf', verbose=1, save_best_only=True,save_format='tf')
            model_filename = f"./Models/{iter_feature}_{iter_gender}_{iter_pers_label}"
            csv_logger = CSVLogger(logfilename, append=True, separator=';')
            exec(f"fit_results_{iter_feature}_{iter_pers_label}_{iter_gender},val_loss_{iter_feature}_{iter_pers_label}_{iter_gender},predicted_val_{iter_feature}_{iter_pers_label}_{iter_gender},predicted_test_{iter_feature}_{iter_pers_label}_{iter_gender}=fit_and_evaluate({iter_gender}_train_{iter_feature}_{iter_pers_label},{iter_gender}_valid_{iter_feature}_{iter_pers_label},{iter_gender}_test_{iter_feature}_X,nb_trial,nb_epochs,model_filename,csv_logger)")
            exec(f"df_validation_loss.at[i,'val_loss']=val_loss_{iter_feature}_{iter_pers_label}_{iter_gender}")
            exec(f"df_validation_loss.at[i,'Pers_Label']=iter_pers_label")
            exec(f"df_validation_loss.at[i,'Feature']=iter_feature")
            exec(f"df_validation_loss.at[i,'Profile_Split']=iter_gender")
            i = i+1
            if (iter_pers_label=='o'):
                exec(f"df_predicted_val_{iter_feature}_{iter_gender} = pd.DataFrame(data=predicted_val_{iter_feature}_{iter_pers_label}_{iter_gender},columns=['o'])") 
                exec(f"df_predicted_test_{iter_feature}_{iter_gender} = pd.DataFrame(data=predicted_test_{iter_feature}_{iter_pers_label}_{iter_gender},columns=['o'])") 
            else:
                exec(f"df_predicted_val_{iter_feature}_{iter_gender}[iter_pers_label]=predicted_val_{iter_feature}_{iter_pers_label}_{iter_gender}")
                exec(f"df_predicted_test_{iter_feature}_{iter_gender}[iter_pers_label]=predicted_test_{iter_feature}_{iter_pers_label}_{iter_gender}")
            
        exec(f"df_predicted_val_{iter_feature}_{iter_gender}.to_csv('{results_dir}/{iter_feature}_{iter_gender}_val.csv',index=False)")
        exec(f"df_predicted_test_{iter_feature}_{iter_gender}.to_csv('{results_dir}/{iter_feature}_{iter_gender}_test.csv',index=False)")

        
df_validation_loss.to_csv(results_dir+"/ValidationLoss.csv",index=False)
# Out:
# Trial 53 Complete [00h 00m 06s]
# val_loss: 1.0555652379989624
#
# Best val_loss So Far: 1.0505422353744507
# Total elapsed time: 00h 14m 10s
#
# Search: Running Trial #54
#
# Hyperparameter    |Value             |Best Value So Far
# structured_data...|True              |False
# structured_data...|False             |False
# structured_data...|3                 |3
# structured_data...|16                |16
# structured_data...|0.5               |0.5
# structured_data...|64                |64
# regression_head...|0.25              |0.25
# optimizer         |adam_weight_decay |adam_weight_decay
# learning_rate     |0.0001            |0.0001
# structured_data...|16                |16
#
# Epoch 1/1000
# 81/81 [==============================] - 1s 4ms/step - loss: 1.8978 - mean_squared_error: 1.8978 - val_loss: 1.1108 - val_mean_squared_error: 1.1108
# Epoch 2/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.9162 - mean_squared_error: 1.9162 - val_loss: 1.1103 - val_mean_squared_error: 1.1103
# Epoch 3/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8171 - mean_squared_error: 1.8171 - val_loss: 1.1098 - val_mean_squared_error: 1.1098
# Epoch 4/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.8734 - mean_squared_error: 1.8734 - val_loss: 1.1096 - val_mean_squared_error: 1.1096
# Epoch 5/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.8962 - mean_squared_error: 1.8962 - val_loss: 1.1089 - val_mean_squared_error: 1.1089
# Epoch 6/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.9328 - mean_squared_error: 1.9328 - val_loss: 1.1080 - val_mean_squared_error: 1.1080
# Epoch 7/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.9056 - mean_squared_error: 1.9056 - val_loss: 1.1069 - val_mean_squared_error: 1.1069
# Epoch 8/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8692 - mean_squared_error: 1.8692 - val_loss: 1.1055 - val_mean_squared_error: 1.1055
# Epoch 9/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8275 - mean_squared_error: 1.8275 - val_loss: 1.1040 - val_mean_squared_error: 1.1040
# Epoch 10/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.8254 - mean_squared_error: 1.8254 - val_loss: 1.1028 - val_mean_squared_error: 1.1028
# Epoch 11/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8090 - mean_squared_error: 1.8090 - val_loss: 1.1019 - val_mean_squared_error: 1.1019
# Epoch 12/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8102 - mean_squared_error: 1.8102 - val_loss: 1.0996 - val_mean_squared_error: 1.0996
# Epoch 13/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8973 - mean_squared_error: 1.8973 - val_loss: 1.0979 - val_mean_squared_error: 1.0979
# Epoch 14/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8168 - mean_squared_error: 1.8168 - val_loss: 1.0961 - val_mean_squared_error: 1.0961
# Epoch 15/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8116 - mean_squared_error: 1.8116 - val_loss: 1.0934 - val_mean_squared_error: 1.0934
# Epoch 16/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7802 - mean_squared_error: 1.7802 - val_loss: 1.0921 - val_mean_squared_error: 1.0921
# Epoch 17/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8354 - mean_squared_error: 1.8354 - val_loss: 1.0898 - val_mean_squared_error: 1.0898
# Epoch 18/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.8321 - mean_squared_error: 1.8321 - val_loss: 1.0878 - val_mean_squared_error: 1.0878
# Epoch 19/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7747 - mean_squared_error: 1.7747 - val_loss: 1.0857 - val_mean_squared_error: 1.0857
# Epoch 20/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7952 - mean_squared_error: 1.7952 - val_loss: 1.0841 - val_mean_squared_error: 1.0841
# Epoch 21/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7718 - mean_squared_error: 1.7718 - val_loss: 1.0821 - val_mean_squared_error: 1.0821
# Epoch 22/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7288 - mean_squared_error: 1.7288 - val_loss: 1.0797 - val_mean_squared_error: 1.0797
# Epoch 23/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.7220 - mean_squared_error: 1.7220 - val_loss: 1.0774 - val_mean_squared_error: 1.0774
# Epoch 24/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7355 - mean_squared_error: 1.7355 - val_loss: 1.0765 - val_mean_squared_error: 1.0765
# Epoch 25/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7527 - mean_squared_error: 1.7527 - val_loss: 1.0736 - val_mean_squared_error: 1.0736
# Epoch 26/1000
# 81/81 [==============================] - 0s 4ms/step - loss: 1.7525 - mean_squared_error: 1.7525 - val_loss: 1.0715 - val_mean_squared_error: 1.0715
# Epoch 27/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7198 - mean_squared_error: 1.7198 - val_loss: 1.0707 - val_mean_squared_error: 1.0707
# Epoch 28/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.8341 - mean_squared_error: 1.8341 - val_loss: 1.0685 - val_mean_squared_error: 1.0685
# Epoch 29/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7533 - mean_squared_error: 1.7533 - val_loss: 1.0663 - val_mean_squared_error: 1.0663
# Epoch 30/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7204 - mean_squared_error: 1.7204 - val_loss: 1.0644 - val_mean_squared_error: 1.0644
# Epoch 31/1000
# 81/81 [==============================] - 0s 2ms/step - loss: 1.6943 - mean_squared_error: 1.6943 - val_loss: 1.0625 - val_mean_squared_error: 1.0625
# Epoch 32/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.7153 - mean_squared_error: 1.7153 - val_loss: 1.0612 - val_mean_squared_error: 1.0612
# Epoch 33/1000
# 81/81 [==============================] - 0s 3ms/step - loss: 1.6987 - mean_squared_error: 1.6987 - val_loss: 1.0607 - val_mean_squared_error: 1.0607
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-394-69e7ac7a966f> in <module>
#      56             model_filename = f"./Models/{iter_feature}_{iter_gender}_{iter_pers_label}"
#      57             csv_logger = CSVLogger(logfilename, append=True, separator=';')
# ---> 58             exec(f"fit_results_{iter_feature}_{iter_pers_label}_{iter_gender},val_loss_{iter_feature}_{iter_pers_label}_{iter_gender},predicted_val_{iter_feature}_{iter_pers_label}_{iter_gender},predicted_test_{iter_feature}_{iter_pers_label}_{iter_gender}=fit_and_evaluate({iter_gender}_train_{iter_feature}_{iter_pers_label},{iter_gender}_valid_{iter_feature}_{iter_pers_label},{iter_gender}_test_{iter_feature}_X,nb_trial,nb_epochs,model_filename,csv_logger)")
#      59             exec(f"df_validation_loss.at[i,'val_loss']=val_loss_{iter_feature}_{iter_pers_label}_{iter_gender}")
#      60             exec(f"df_validation_loss.at[i,'Pers_Label']=iter_pers_label")
#
# <string> in <module>
#
# <ipython-input-394-69e7ac7a966f> in fit_and_evaluate(tf_train_set, tf_val_set, X_test, TRIALS, EPOCHS, model_filename, csv_logger)
#      32     model_reg = None
#      33     model_reg = ak.StructuredDataRegressor(max_trials=TRIALS, overwrite=True)
# ---> 34     fit_results = model_reg.fit(tf_train_set, epochs=EPOCHS, validation_split=0.15,callbacks=[csv_logger])#validation_data=tf_val_set
#      35     validation_loss = model_reg.evaluate(tf_val_set)
#      36     predicted_y_val = model_reg.predict(tf_val_set)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/tasks/structured_data.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     137         self.check_in_fit(x)
#     138
# --> 139         history = super().fit(
#     140             x=x,
#     141             y=y,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/auto_model.py in fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     282             )
#     283
# --> 284         history = self.tuner.search(
#     285             x=dataset,
#     286             epochs=epochs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/engine/tuner.py in search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     185         self.hypermodel.build(hp)
#     186         self.oracle.update_space(hp)
# --> 187         super().search(
#     188             epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     189         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     174
#     175             self.on_trial_begin(trial)
# --> 176             self.run_trial(trial, *fit_args, **fit_kwargs)
#     177             self.on_trial_end(trial)
#     178         self.on_search_end()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     193             copied_fit_kwargs["callbacks"] = callbacks
#     194
# --> 195             history = self._build_and_fit_model(trial, fit_args, copied_fit_kwargs)
#     196             for metric, epoch_values in history.history.items():
#     197                 if self.oracle.objective.direction == "min":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/engine/tuner.py in _build_and_fit_model(self, trial, fit_args, fit_kwargs)
#      99         self.adapt(model, fit_kwargs["x"])
#     100
# --> 101         _, history = utils.fit_with_adaptive_batch_size(
#     102             model, self.hypermodel.hypermodel.batch_size, **fit_kwargs
#     103         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/utils/utils.py in fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs)
#      85
#      86 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
# ---> 87     history = run_with_adaptive_batch_size(
#      88         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      89     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/utils/utils.py in run_with_adaptive_batch_size(batch_size, func, **fit_kwargs)
#      98     while batch_size > 0:
#      99         try:
# --> 100             history = func(x=x, validation_data=validation_data, **fit_kwargs)
#     101             break
#     102         except tf.errors.ResourceExhaustedError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/autokeras/utils/utils.py in <lambda>(**kwargs)
#      86 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
#      87     history = run_with_adaptive_batch_size(
# ---> 88         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      89     )
#      90     return model, history
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1227           epoch_logs.update(val_logs)
#    1228
# -> 1229         callbacks.on_epoch_end(epoch, epoch_logs)
#    1230         training_logs = epoch_logs
#    1231         if self.stop_training:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     433     logs = self._process_logs(logs)
#     434     for callback in self.callbacks:
# --> 435       callback.on_epoch_end(epoch, logs)
#     436
#     437   def on_train_batch_begin(self, batch, logs=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1367     # pylint: disable=protected-access
#    1368     if self.save_freq == 'epoch':
# -> 1369       self._save_model(epoch=epoch, logs=logs)
#    1370
#    1371   def _should_save_on_batch(self, batch):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1416               self.best = current
#    1417               if self.save_weights_only:
# -> 1418                 self.model.save_weights(
#    1419                     filepath, overwrite=True, options=self._options)
#    1420               else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in save_weights(self, filepath, overwrite, save_format, options)
#    2222       else:
#    2223         session = backend.get_session()
# -> 2224       self._trackable_saver.save(filepath, session=session, options=options)
#    2225       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    2226       checkpoint_management.update_checkpoint_state_internal(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in save(self, file_prefix, checkpoint_number, session, options)
#    1216
#    1217     file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1218     save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1219         file_prefix_tensor, object_graph_tensor, options)
#    1220     if new_feed_additions:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1153     """
#    1154     (named_saveable_objects, graph_proto,
# -> 1155      feed_additions) = self._gather_saveables(
#    1156          object_graph_tensor=object_graph_tensor)
#    1157     if (self._last_save_object_graph != graph_proto
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/util.py in _gather_saveables(self, object_graph_tensor)
#    1120     """Wraps _serialize_object_graph to include the object graph proto."""
#    1121     (named_saveable_objects, graph_proto,
# -> 1122      feed_additions) = self._graph_view.serialize_object_graph()
#    1123     if object_graph_tensor is None:
#    1124       with ops.device("/cpu:0"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/graph_view.py in serialize_object_graph(self)
#     406     """
#     407     trackable_objects, path_to_root = self._breadth_first_traversal()
# --> 408     return self._serialize_gathered_objects(
#     409         trackable_objects, path_to_root)
#     410
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/graph_view.py in _serialize_gathered_objects(self, trackable_objects, path_to_root, object_map, call_with_mapped_captures)
#     366     for node_id, node in enumerate(trackable_objects):
#     367       node_ids[node] = node_id
# --> 368     slot_variables = _serialize_slot_variables(
#     369         trackable_objects=trackable_objects,
#     370         node_ids=node_ids,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/graph_view.py in _serialize_slot_variables(trackable_objects, node_ids, object_names)
#      96         # Note: dir() is used rather than hasattr() here to avoid triggering
#      97         # custom __getattr__ code, see b/152031870 for context.
# ---> 98         or "_create_or_restore_slot_variable" in dir(trackable)):
#      99       naming_scheme = _slot_variable_naming_for_optimizer(
#     100           optimizer_path=object_names[trackable])
#
# KeyboardInterrupt:

# %%
#male_valid_talkturn_o
# Out:
# <TensorSliceDataset shapes: ((5,), ()), types: (tf.float32, tf.float64)>

# %%
#from tensorflow.keras.models import load_model
#loaded_model = load_model("./Models/talkturn_male_o", custom_objects=ak.CUSTOM_OBJECTS)
#loaded_model#.evaluate(male_train_talkturn_o)
#model_reg.evaluate(tf_val_set)

# %% [markdown]
# ## Decision Fusion
# Read the predictions for each modality for each personality label.

# %%
df_talkturn_valid_male_meta.head()
# Out:
#     ID_y minute
# 19  80.0      0
# 21  80.0      1
# 23  80.0      2
# 25  80.0      3
# 27  80.0      4

# %%
ocean_male_valid.head()
# Out:
#     OPENMINDEDNESS_Z  CONSCIENTIOUSNESS_Z  EXTRAVERSION_Z  AGREEABLENESS_Z  \
# 19          0.998121             2.238958       -0.705557         0.095138
# 21          0.998121             2.238958       -0.705557         0.095138
# 23          0.998121             2.238958       -0.705557         0.095138
# 25          0.998121             2.238958       -0.705557         0.095138
# 27          0.998121             2.238958       -0.705557         0.095138
#
#     NEGATIVEEMOTIONALITY_Z
# 19               -2.195649
# 21               -2.195649
# 23               -2.195649
# 25               -2.195649
# 27               -2.195649

# %%
df_predicted_val_talkturn_male.head()
# Out:
#           o         c         e         a         n
# 0  0.308138 -0.042873 -0.290274 -0.384957 -0.754948
# 1  0.197639 -0.002881 -0.226412 -0.002106 -0.827117
# 2  0.315538 -0.065446 -0.374467  0.144767 -0.561742
# 3  0.137070 -0.011441 -0.248386 -0.266303 -0.777699
# 4  0.308541 -0.089578 -0.220579 -0.169864 -0.654140

# %%
frames = [df_talkturn_valid_male_meta.reset_index(drop=True), df_predicted_val_talkturn_male.reset_index(drop=True), ocean_male_valid.reset_index(drop=True)]

result = pd.concat(frames, axis=1)

# %%
result
# Out:
#       ID_y minute         o         c         e         a         n  \
# 0     80.0      0  0.308138 -0.042873 -0.290274 -0.384957 -0.754948
# 1     80.0      1  0.197639 -0.002881 -0.226412 -0.002106 -0.827117
# 2     80.0      2  0.315538 -0.065446 -0.374467  0.144767 -0.561742
# 3     80.0      3  0.137070 -0.011441 -0.248386 -0.266303 -0.777699
# 4     80.0      4  0.308541 -0.089578 -0.220579 -0.169864 -0.654140
# ..     ...    ...       ...       ...       ...       ...       ...
# 600  183.0      0  0.046132  0.027611 -0.303581 -0.301706 -0.832686
# 601  183.0      1  0.131986  0.024025 -0.232989 -0.258882 -0.706376
# 602  183.0      2 -0.725919 -1.351233 -0.382490  0.001456 -0.539435
# 603  183.0      3  0.049725  0.031264 -0.226336 -0.179005 -0.711360
# 604  183.0      4 -0.170246  0.889537 -0.143389 -0.226504 -0.508110
#
#      OPENMINDEDNESS_Z  CONSCIENTIOUSNESS_Z  EXTRAVERSION_Z  AGREEABLENESS_Z  \
# 0            0.998121             2.238958       -0.705557         0.095138
# 1            0.998121             2.238958       -0.705557         0.095138
# 2            0.998121             2.238958       -0.705557         0.095138
# 3            0.998121             2.238958       -0.705557         0.095138
# 4            0.998121             2.238958       -0.705557         0.095138
# ..                ...                  ...             ...              ...
# 600          0.840368             0.480918        0.243083         0.272626
# 601          0.840368             0.480918        0.243083         0.272626
# 602          0.840368             0.480918        0.243083         0.272626
# 603          0.840368             0.480918        0.243083         0.272626
# 604          0.840368             0.480918        0.243083         0.272626
#
#      NEGATIVEEMOTIONALITY_Z
# 0                 -2.195649
# 1                 -2.195649
# 2                 -2.195649
# 3                 -2.195649
# 4                 -2.195649
# ..                      ...
# 600               -0.312424
# 601               -0.312424
# 602               -0.312424
# 603               -0.312424
# 604               -0.312424
#
# [605 rows x 12 columns]

# %%
for iter_gender in ['male','female']:
    for iter_feature in ['speechtrait','talkturn','sentiment','time']:
        print(f" Gender: {iter_gender}, Feature: {iter_feature}")  
        exec(f"df_predicted_valid_{iter_feature}_{iter_gender}=pd.read_csv('{results_dir}/{iter_feature}_{iter_gender}_val.csv')")
        exec(f"df_predicted_test_{iter_feature}_{iter_gender}=pd.read_csv('{results_dir}/{iter_feature}_{iter_gender}_test.csv')")
# Out:
#  Gender: male, Feature: speechtrait
#  Gender: male, Feature: talkturn
#  Gender: male, Feature: sentiment
#  Gender: male, Feature: time
#  Gender: female, Feature: speechtrait
#  Gender: female, Feature: talkturn
#  Gender: female, Feature: sentiment
#  Gender: female, Feature: time

# %%
df_o_male=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','o'])
df_o_female=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','o'])

df_c_male=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','c'])
df_c_female=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','c'])

df_e_male=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','e'])
df_e_female=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','e'])

df_a_male=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','a'])
df_a_female=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','a'])


df_n_male=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','n'])
df_n_female=pd.DataFrame(columns=['talkturn','sentiment','speechtrait','time','n'])


for iter_gender in ['male','female']:
    for iter_pers_label in ['o','c','e','a','n']:
        for iter_set in ['valid']:
            exec(f"df_{iter_pers_label}_{iter_gender}['talkturn'] = df_predicted_{iter_set}_talkturn_{iter_gender}[iter_pers_label].reset_index(drop=True).copy()")
            exec(f"df_{iter_pers_label}_{iter_gender}['sentiment'] = df_predicted_{iter_set}_sentiment_{iter_gender}[iter_pers_label].reset_index(drop=True).copy()")
            exec(f"df_{iter_pers_label}_{iter_gender}['speechtrait'] = df_predicted_{iter_set}_speechtrait_{iter_gender}[iter_pers_label].reset_index(drop=True).copy()")
            exec(f"df_{iter_pers_label}_{iter_gender}['time'] = df_predicted_{iter_set}_time_{iter_gender}[iter_pers_label].reset_index(drop=True).copy()")
            if iter_pers_label=="o":
                exec(f"df_{iter_pers_label}_{iter_gender}[iter_pers_label] = ocean_{iter_gender}_{iter_set}['OPENMINDEDNESS_Z'].reset_index(drop=True).copy()")
            elif iter_pers_label=="c":
                exec(f"df_{iter_pers_label}_{iter_gender}[iter_pers_label] = ocean_{iter_gender}_{iter_set}['CONSCIENTIOUSNESS_Z'].reset_index(drop=True).copy()")
            elif iter_pers_label=="e":
                exec(f"df_{iter_pers_label}_{iter_gender}[iter_pers_label] = ocean_{iter_gender}_{iter_set}['EXTRAVERSION_Z'].reset_index(drop=True).copy()")
            elif iter_pers_label=="a":    
                exec(f"df_{iter_pers_label}_{iter_gender}[iter_pers_label] = ocean_{iter_gender}_{iter_set}['AGREEABLENESS_Z'].reset_index(drop=True).copy()")
            elif iter_pers_label=="n":    
                exec(f"df_{iter_pers_label}_{iter_gender}[iter_pers_label] = ocean_{iter_gender}_{iter_set}['NEGATIVEEMOTIONALITY_Z'].reset_index(drop=True).copy()")

# %%
df_o_female.iloc[:,4]
# Out:
# 0     -0.421661
# 1     -0.421661
# 2     -0.421661
# 3     -0.421661
# 4     -0.421661
#          ...
# 479    0.998121
# 480    0.998121
# 481    0.998121
# 482    0.998121
# 483    0.998121
# Name: o, Length: 484, dtype: float64

# %%
#from sklearn.linear_model import Ridge
#from sklearn import metrics


#import numpy as np

#clf = Ridge(alpha=1.0)
#clf.fit(df_o_female.iloc[:,0:4], df_o_female.iloc[:,4])
#Ridge()
# Out:
# Ridge()

# %%
#clf.score(df_o_female.iloc[:,0:4], df_o_female.iloc[:,4])
# Out:
# 0.032398642158395274

# %%
#clf.predict(df_o_female.iloc[:,0:4])
# Out:
# array([ 0.35299426,  0.43384809,  0.45714421,  0.40309222,  0.45637238,
#         0.4456977 ,  0.45040842,  0.50015116,  0.40421024,  0.35273536,
#         0.40383476,  0.30417687,  0.45630768,  0.309226  ,  0.46489194,
#         0.40764407,  0.46612263,  0.42411803,  0.45679087,  0.30557645,
#         0.44358067,  0.28972955,  0.40385345,  0.46865526,  0.49296652,
#         0.45155756,  0.46298466,  0.44432679,  0.48615353,  0.45684428,
#         0.44523271,  0.46998093,  0.44490414,  0.43496521,  0.376205  ,
#         0.46795597,  0.48676748,  0.13453291,  0.28951802,  0.48851953,
#         0.4524284 ,  0.46803579, -0.02775933,  0.46389696,  0.44766357,
#         0.41055014,  0.47754246,  0.48354282,  0.24247618,  0.30408884,
#         0.45209448,  0.41031032,  0.38966737,  0.41774991,  0.44649156,
#         0.39082724,  0.11022052,  0.21692118,  0.38703017,  0.25605337,
#         0.44424594, -0.05436763,  0.34981629,  0.14080766,  0.44734898,
#         0.14609072,  0.45860315,  0.47971938,  0.45008402,  0.19010842,
#         0.37314295,  0.04271029,  0.3769381 ,  0.39687415,  0.4520943 ,
#         0.49518098,  0.43027608,  0.37236013,  0.43688226,  0.04307169,
#         0.33945179,  0.41625637,  0.46177727,  0.46784918,  0.46595868,
#         0.46539964, -0.2200601 ,  0.45680664,  0.46942856,  0.46521227,
#         0.47105642,  0.34456061,  0.4732411 ,  0.46232883,  0.45870174,
#         0.45773497,  0.46784225,  0.46017068,  0.48745218,  0.29382294,
#         0.35603219,  0.35941848,  0.33323697,  0.07921715,  0.12939784,
#         0.14389007,  0.38561679,  0.39270874,  0.46570472,  0.42034055,
#         0.43519006,  0.46054947,  0.45521519,  0.47624756,  0.44696974,
#         0.45651315,  0.36275537,  0.47754697, -0.04297218,  0.42095611,
#         0.42000839,  0.44705654,  0.45700985,  0.39802869,  0.45245966,
#         0.45759591,  0.47386779,  0.4503644 ,  0.44028063,  0.44927146,
#         0.45824987,  0.45027623,  0.48123807,  0.45070969,  0.45247842,
#         0.46316925,  0.46826485,  0.4570475 , -0.00569044,  0.47141862,
#         0.10580903,  0.4570241 ,  0.47645009,  0.44219357,  0.51732018,
#         0.4470486 ,  0.41511175,  0.48374277,  0.44063694,  0.41956626,
#         0.45110511,  0.44865041,  0.47201842,  0.41249386,  0.40014605,
#         0.4509935 ,  0.48568543,  0.37023141,  0.45023005,  0.40974153,
#         0.39849688,  0.48658832,  0.45200963,  0.45780065,  0.43700632,
#         0.47230282,  0.43697279,  0.4326898 ,  0.44577239,  0.42036281,
#         0.46129629,  0.47435474,  0.23588086,  0.44507502,  0.43119001,
#         0.4560909 ,  0.43910994,  0.45423904,  0.41984578,  0.41020262,
#         0.49575494,  0.44942438,  0.47341534,  0.40476465,  0.44000784,
#         0.46326974,  0.4729185 ,  0.45406386,  0.47173098,  0.39269434,
#         0.49352461,  0.44485913,  0.4375658 ,  0.43207548,  0.45519829,
#         0.4765035 ,  0.45217391,  0.46289133,  0.47063984,  0.44711163,
#         0.44787159,  0.48951542,  0.4539558 ,  0.4914898 ,  0.46891943,
#         0.42711747,  0.39023425,  0.4641979 ,  0.4667065 ,  0.3939075 ,
#         0.40500622,  0.300822  ,  0.4499177 ,  0.49425836,  0.4810124 ,
#         0.478992  ,  0.47140854,  0.50141068,  0.50711311,  0.46087003,
#         0.51188492,  0.45770569,  0.41177878,  0.44289492,  0.4318714 ,
#         0.48957827,  0.45636694,  0.45162655,  0.47089659,  0.47214265,
#         0.46935092,  0.57388366,  0.42794258,  0.44492386,  0.45270736,
#         0.46375585,  0.47149398,  0.46390354,  0.4737754 ,  0.45577501,
#         0.45915446,  0.45773917,  0.41062798,  0.45958023,  0.46818623,
#         0.46393816,  0.46407744,  0.47673524,  0.45362337,  0.46598365,
#         0.44892197,  0.95207576,  0.47943623,  0.4657564 ,  0.48802289,
#         0.4694765 ,  0.45498505,  0.4220121 ,  0.47606104,  0.55078843,
#         0.44158934,  0.43083205,  0.46112882,  0.46269923,  0.44720334,
#         0.43848072,  0.41489466,  0.46180958,  0.46475737,  0.45199911,
#         0.4702085 ,  0.4675693 ,  0.47974375,  0.46035471,  0.45242893,
#         0.44711983,  0.46411888,  0.46353177,  0.4529961 ,  0.48049844,
#         0.39956892,  0.44431837,  0.48209832,  0.47868591,  0.47149917,
#         0.4251045 ,  0.32291199,  0.47986935,  0.42717937,  0.47314217,
#         0.46694341,  0.46857165,  0.45923238,  0.43244336,  0.44605446,
#         0.47986118,  0.45764298,  0.43621659,  0.47493814,  0.44697003,
#         0.44936506,  0.48759312,  0.45755605,  0.44007026,  0.46150135,
#         0.47594388,  0.44728582,  0.45794331,  0.45113679,  0.45575873,
#         0.46269833,  0.46585084,  0.43868476,  0.44245328,  0.4782247 ,
#         0.45389891,  0.47195818,  0.43531051,  0.45875182,  0.48227938,
#         0.46303026,  0.46807989,  0.45193034,  0.43777901,  0.45149995,
#         0.50878837,  0.4229388 ,  0.48042758,  0.27792809,  0.45588986,
#         0.48360963,  0.36285184,  0.45133267,  0.50656669,  0.43802744,
#         0.44454312,  0.41365166,  0.46486722,  0.42921704,  0.46108748,
#         0.46083402,  0.46916535,  0.45099663,  0.44439666,  0.47145642,
#         0.48542533,  0.50276153,  0.46867005,  0.45763148,  0.47398157,
#         0.46945612,  0.45805638,  0.53792021,  0.50357063,  0.44178201,
#         0.48444271,  0.4753533 ,  0.35922931,  0.45422544,  0.47762453,
#         0.45243453,  0.47507848,  0.47592388,  0.44797471,  0.43732961,
#         0.45456004,  0.46378764,  0.20830786,  0.44675237,  0.45101567,
#         0.48103641,  0.46750847,  0.19425601,  0.44568186,  0.4840534 ,
#         0.38374737,  0.40576897,  0.44107598,  0.43608002,  0.43427087,
#         0.48498471,  0.49281769,  0.37025566,  0.48310221,  0.45843957,
#         0.48087732,  0.52495111,  0.44611073,  0.49339684,  0.44745532,
#         0.47558945,  0.45482666,  0.46768702,  0.47075443,  0.46616369,
#         0.33792565,  0.45569973,  0.49041009,  0.47064887,  0.47772018,
#         0.4639748 ,  0.44167213,  0.44982339,  0.43934333,  0.48382282,
#         0.46290269,  0.44935081,  0.42899513,  0.45998407,  0.44172326,
#         0.46898843,  0.53554127,  0.47818752,  0.44653595,  0.455705  ,
#         0.45286509,  0.45165223,  0.43398952,  0.47333676,  0.45438704,
#         0.42865528,  0.41826911,  0.4583627 ,  0.45631015,  0.46464083,
#         0.45123878,  0.44717752,  0.45186648,  0.49769976,  0.44491882,
#         0.47220497,  0.45750249,  0.35581058,  0.39817379,  0.46059402,
#         0.46579139,  0.45088635,  0.45603607,  0.47873771,  0.45889098,
#         0.43651072,  0.46694237,  0.41295581,  0.51265961,  0.44621469,
#         0.17229831,  0.00808266,  0.45102827,  0.47737722,  0.45733952,
#         0.48575022,  0.44407879,  0.48174027,  0.46728496,  0.45956795,
#         0.46246943,  0.17916261,  0.45525526,  0.45620884,  0.00150738,
#         0.46265067,  0.42754131, -0.80462332,  0.40958938,  0.37459273,
#         0.32185079,  0.45523819,  0.45608585,  0.40269144,  0.44065897,
#         0.06780108,  0.46743433,  0.36667154,  0.45901348,  0.46856687,
#         0.45195369,  0.44998206,  0.4342919 ,  0.48003283,  0.41684897,
#         0.48353314,  0.45889846,  0.46144626,  0.4565994 ])

# %%
df_talkturn_test_male_meta.to_csv('./Results/test_male_meta.csv')
df_talkturn_test_female_meta.to_csv('./Results/test_female_meta.csv')

# %%
df_talkturn_test_male_meta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b276ed38cde1> in <module>
# ----> 1 df_talkturn_test_male_meta
#
# NameError: name 'df_talkturn_test_male_meta' is not defined
